# %% [markdown]
# <a href="https://colab.research.google.com/github/shukrullo24/Python-darslari/blob/main/For_opratori_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `for` sikli amaliyot

# %% [markdown]
# Kamida 5 elementdan iborat ismlar degan ro'yxat tuzing, va ro'yxatdagi har bir ismga takrorlanuvchi xabar yozing

# %%
sinfdoshlar = ['oybek', 'islom', 'maqsud', 'muzaffar', 'shohjahon']
for sinfdosh in sinfdoshlar:
  print(f"Salom {sinfdosh}, ishlaring yaxshimi?")
# Out:
# Salom oybek, ishlaring yaxshimi?
# Salom islom, ishlaring yaxshimi?
# Salom maqsud, ishlaring yaxshimi?
# Salom muzaffar, ishlaring yaxshimi?
# Salom shohjahon, ishlaring yaxshimi?

# %% [markdown]
# Yuoqirdagi tsikl tugaganidan so'ng, ekranga "Kod n marta takrorlandi" degan xabarni chiqaring (n o'rniga kod necha marta takrorlanganini yozing)

# %%
sinfdoshlar = ['oybek', 'islom', 'maqsud', 'muzaffar', 'shohjahon']
for sinfdosh in sinfdoshlar:
  print(f"Salom {sinfdosh.capitalize()}, ahvollaring qalay?")
print(f"Kod {len(sinfdoshlar)} marta takrorlandi.")
# Out:
# Salom Oybek, ahvollaring qalay?
# Salom Islom, ahvollaring qalay?
# Salom Maqsud, ahvollaring qalay?
# Salom Muzaffar, ahvollaring qalay?
# Salom Shohjahon, ahvollaring qalay?
# Kod 5 marta takrorlandi.

# %% [markdown]
# 10 dan 100 gacha bo'lgan toq sonlar ro'yxatini tuzing. Ro'yxatning xar bir elementining kubini yangi qatordan konsolga chiqaring.

# %%
sonlar = list(range(11, 101, 2))
for son in sonlar:
  print(f"{son} ning kubi {son**3} ga teng.")
# Out:
# 11 ning kubi 1331 ga teng.
# 13 ning kubi 2197 ga teng.
# 15 ning kubi 3375 ga teng.
# 17 ning kubi 4913 ga teng.
# 19 ning kubi 6859 ga teng.
# 21 ning kubi 9261 ga teng.
# 23 ning kubi 12167 ga teng.
# 25 ning kubi 15625 ga teng.
# 27 ning kubi 19683 ga teng.
# 29 ning kubi 24389 ga teng.
# 31 ning kubi 29791 ga teng.
# 33 ning kubi 35937 ga teng.
# 35 ning kubi 42875 ga teng.
# 37 ning kubi 50653 ga teng.
# 39 ning kubi 59319 ga teng.
# 41 ning kubi 68921 ga teng.
# 43 ning kubi 79507 ga teng.
# 45 ning kubi 91125 ga teng.
# 47 ning kubi 103823 ga teng.
# 49 ning kubi 117649 ga teng.
# 51 ning kubi 132651 ga teng.
# 53 ning kubi 148877 ga teng.
# 55 ning kubi 166375 ga teng.
# 57 ning kubi 185193 ga teng.
# 59 ning kubi 205379 ga teng.
# 61 ning kubi 226981 ga teng.
# 63 ning kubi 250047 ga teng.
# 65 ning kubi 274625 ga teng.
# 67 ning kubi 300763 ga teng.
# 69 ning kubi 328509 ga teng.
# 71 ning kubi 357911 ga teng.
# 73 ning kubi 389017 ga teng.
# 75 ning kubi 421875 ga teng.
# ...

# %% [markdown]
# Foydalanuvchidan 5 ta eng sevimli kinolarini kiritshni so'rang, va kinolar degan ro'yxatga saqlab oling. Natijani konsolga chiqaring.

# %%
kinolar = []
for kino in range(5):
  kino = kinolar.append(input("Kino nomini kiriting: "))
print(f"Siz kiritgan kinolar quyidagilar: {kinolar}")
# Out:
# Kino nomini kiriting: a
# Kino nomini kiriting: b
# Kino nomini kiriting: c
# Kino nomini kiriting: d
# Kino nomini kiriting: f
# Siz kiritgan kinolar quyidagilar: ['a', 'b', 'c', 'd', 'f']

# %% [markdown]
# Foydalanuvchidan bugun nechta odam bilan uchrashganini (suhbatlashganini) so'rang, va har bir suhbatlashgan odamning ismini birma-bir so'rab ro'yxatga yozing. Ro'yxatni konsolga chiqaring.

# %%
num = int(input("Bugun necha kishi bilan suhbatlashdingiz?>>> "))
people = []
for n in range(num):
  people.append(input(f"{n+1}-uchratgan odamingiz?>>> "))
print("Bugun siz uchratgan insonlar:")
for person in people:
  print(person.capitalize())
# Out:
# Bugun necha kishi bilan suhbatlashdingiz?>>> 2
# 1-uchratgan odamingiz?>>> a
# 2-uchratgan odamingiz?>>> b
# Bugun siz uchratgan insonlar:
# A
# B

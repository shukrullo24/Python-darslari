# %% [markdown]
# <a href="https://colab.research.google.com/github/shukrullo24/Python-darslari/blob/main/Pandas_Kutubxonasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series ma'lumotlar tuzilmasi

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %% [markdown]
# # Lug'atdan series yaratish

# %%
cars_dict = {"malibu": 30000, "Lacetti": 20000, "Matiz": 5000, "Onix": 20000}
type(cars_dict)
# Out:
# dict

# %%
cars_dict
# Out:
# {'malibu': 30000, 'Lacetti': 20000, 'Matiz': 5000, 'Onix': 20000}

# %%
cars1 = Series(cars_dict)
cars1
# Out:
# malibu     30000
# Lacetti    20000
# Matiz       5000
# Onix       20000
# dtype: int64

# %%
"tracker" in cars1
# Out:
# False

# %%
 "malibu" in cars1
# Out:
# True

# %%
cars1["Onix"]
# Out:
# np.int64(20000)

# %%
models = ['honda', 'mazda', 'Lacetti', 'malibu', 'Toyota']

# %%
cars2 = Series(cars1, index=models)
cars2
# Out:
# honda          NaN
# mazda          NaN
# Lacetti    20000.0
# malibu     30000.0
# Toyota         NaN
# dtype: float64

# %%
cars1.isnull()
# Out:
# malibu     False
# Lacetti    False
# Matiz      False
# Onix       False
# dtype: bool

# %%
cars2.isnull()
# Out:
# honda       True
# mazda       True
# Lacetti    False
# malibu     False
# Toyota      True
# dtype: bool

# %%
cars2.name="Avtosalon"

# %%
cars2.index.name = "Modellar", "Narxlar"

# %%
cars2.hasnans
# Out:
# True

# %%
cars2
# Out:
# (Modellar, Narxlar)
# honda          NaN
# mazda          NaN
# Lacetti    20000.0
# malibu     30000.0
# Toyota         NaN
# Name: Avtosalon, dtype: float64

# %% [markdown]
# <a href="https://colab.research.google.com/github/shukrullo24/Python-darslari/blob/main/IF_ELSE_amaliyot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # If-Else

# %% [markdown]
# `if` operatori

# %%
avtolar = ['audi', 'bmw', 'volvo', 'kia', 'hyundai']
avtolar
# Out:
# ['audi', 'bmw', 'volvo', 'kia', 'hyundai']

# %%
for avto in avtolar:
  if avto == "bmw":
    print(avto.upper())
  else:
    print(avto.title())
# Out:
# Audi
# BMW
# Volvo
# Kia
# Hyundai

# %% [markdown]
# `lower()` metodidan foydalanish

# %%
ism = "Ali"
ism.lower() == "ali"
# Out:
# True

# %%
ism = input("ismingiz nima?\n>>>")
if ism.lower() != "ali":
  print(f"Uzur {ism.title()}, biz Alini kutayapmiz.")
else:
  print(f"Salom {ism.title()}")
# Out:
# ismingiz nima?
# >>>ali
# Salom Ali

# %% [markdown]
# Sonlarni taqqoslash

# %%
javob = float(input("12x6 nechiga teng?\n>>>"))
if javob != 72:
  print("javob xato")
else:
  print(f"To'g'ri javob {12*6} ga teng.")
# Out:
# 12x6 nechiga teng?
# >>>72
# To'g'ri javob 72 ga teng.

# %% [markdown]
# 18 yoshdan kattalarga kirishga ruxsat berish

# %%
yosh = int(input("Yoshingiz nechida?\n>>>"))
if yosh >= 18:
  print("Xush kelibsiz!")
else:
  print("Sizga kirish mumkin emas")
# Out:
# Yoshingiz nechida?
# >>>18
# Xush kelibsiz!

# %% [markdown]
# 8 tadan ko'proq belgili loginni shart qilib belgilash

# %%
login = input("Yangi login kiriting: ")
if len(login) < 8:
  print("Login eng kamida 8ta elementdan iborat bo'lishi kerak!")
else:
  print("Login qabul qilindi.")
print(f"Sizning loginingiz: {login}")
# Out:
# Yangi login kiriting: shukrulloh
# Login qabul qilindi.
# Sizning loginingiz: shukrulloh

# %% [markdown]
# Qisqa kodlarni bir qatorda yozish

# %%
yosh = int(input("Yoshingizni kiriting: "))
if yosh > 65: print("Siz COVID-19 risk guruhida ekansiz")
else: print("Ko'chaga chiqishda maska taqishni unutmang")
# Out:
# Yoshingizni kiriting: 27
# Ko'chaga chiqishda maska taqishni unutmang

# %%
x, y = 25, 5
print("x>y") if x>y else print("x<y")
# Out:
# x>y

# %% [markdown]
# # IF-ELSE amaliyot

# %% [markdown]
# Yangi `cars = ['toyota', 'mazda', 'hyundai', 'gm', 'kia']` degan ro'yxat tuzing, ro'yxat elementlarining birinchi harfini katta qilib konsolga chiqaring. GM uchun ikkala harfni katta qiling.

# %%
cars = ['toyota', 'mazda', 'hyundai', 'gm', 'kia']
for car in cars:
  if car == "gm":
    print(car.upper())
  else:
    print(car.capitalize())
# Out:
# Toyota
# Mazda
# Hyundai
# GM
# Kia

# %% [markdown]
# Foydalanuvchi login ismini so'rang. Agar login admin bo'lsa, `"Xush kelibsiz, Admin. Foydalanuvchilar ro'yxatini ko'rasizmi?"` xabarini konsolga chiqaring. Aks holda, "Xush kelibsiz, `{foydalanuvchi_ismi}!`"  matnini konsolga chiqaring.

# %%
foydalanuvchi = input("Foydalanuvchi ismingizni kiriting: ")
if foydalanuvchi == "admin":
  print("Hush kelibsiz admin, Foydalanuvchilar ro'yxatini ko'rasizmi?")
else: print(f"Hush kelibsiz {foydalanuvchi.capitalize()}")
# Out:
# Foydalanuvchi ismingizni kiriting: soginboev shukrulloh
# Hush kelibsiz Soginboev shukrulloh

# %% [markdown]
# Foydalanuvchidan 2 ta son kiritishni so'rang. Agar ikki son bir-biriga teng bo'lsa, "Sonlar teng" ekan degan yozuvni konsolga chiqaring.

# %%
son1 = int(input("Birinchi sonni kiriting: "))
son2 = int(input("Ikkinchi sonni kiriting: "))
if son1 == son2: print("Sonlar o'zaro teng")
elif son1 > son2:
  print(f"{son1}>{son2}")
else: print(f"{son1}<{son2}")
# Out:
# Birinchi sonni kiriting: 7
# Ikkinchi sonni kiriting: 5
# 7>5

# %% [markdown]
# Foydalanuvchidan istalgan son kiritishni so'rang. Agar son manfiy bo'lsa konsolga "Manfiy son", agar musbat bo'lsa "Musbat son" degan xabarni chiqaring.

# %%
ixtiyoriy_son = int(input("Istalgan son kiriting, uning musbat yoki manfiligini aniqlab beraman:\n>>> "))
if ixtiyoriy_son < 0:
  print("Kiritilgan son manfiy")
else: print("Kiritilgan son musbat")
# Out:
# Istalgan son kiriting, uning musbat yoki manfiligini aniqlab beraman:
# >>> -1
# Kiritilgan son manfiy

# %% [markdown]
# Foydalanuvchidan son kiritishni so'rang, agar son musbat bo'lsa uning ildizini hisoblab konsolga chiqaring. Agar son manfiy bo'lsa, "Musbat son kiriting" degan xabarni chiqaring.

# %%
son = int(input("Istalgan musbat son kiriting, men uning ildizini hisoblab beraman\n>>>"))
if son >= 0:
  print(f"{son**0.5}")
else: print("Musbat son kiriting.")
# Out:
# Istalgan musbat son kiriting, men uning ildizini hisoblab beraman
# >>>9
# 3.0

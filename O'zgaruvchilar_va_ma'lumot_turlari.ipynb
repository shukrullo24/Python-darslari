# %% [markdown]
# <a href="https://colab.research.google.com/github/shukrullo24/Python-darslari/blob/main/O'zgaruvchilar_va_ma'lumot_turlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # O'zgaruvchilar mavzusida amaliyot

# %% [markdown]
# 1. "Hello world" matnini yangi o'zgaruvchiga yuklang va print() funksiyasi yordamida uni konsolga chiqaring

# %%
# 1
salom = "Assalomu aleykum"
print(salom)
# Out:
# Assalomu aleykum

# %% [markdown]
# 2. "xabar" deb nomlangan o'zgaruvchiga biror matn yuklang va konsolga chiqaring, kyien esa o'zgaruvchiga yangi qiymat berib uni ham konsolga chiqaring

# %%
# 2
xabar = "Ertaga ob-havo sovuq bo'lishi kutilmoqda"
print(xabar)
# Out:
# Ertaga ob-havo sovuq bo'lishi kutilmoqda

# %% [markdown]
# 3. "class" deb nomlangan o'zgaruvchi yarating, unga biror qiymat bering va konsolga chiqaring (siz kutgan natija chiqdimi?)

# %%
# 3
class = "Indinga ob-havo minus darajaga tushishi kutilmoqda"
# Out:
#   File "/tmp/ipython-input-3432109582.py", line 2
#     class = "Indinga ob-havo minus darajaga tushishi kutilmoqda"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# 4. Quyidagi kodni bajaring:
# radius = 5
# pi = 3.14159
# aylana_yuzi = pi * radius**2
# print("Radiusi" , radius, "ga teng aylananing yuzi=", aylana_yuzi) -->

# %%
# 4
radius = 5
pi = 3.14
aylana_yuzi = pi * radius**2
print("Radiusi" , radius, "cm ga teng aylananing yuzi=", aylana_yuzi, "cm ga teng.")
# Out:
# Radiusi 5 cm ga teng aylananing yuzi= 78.5 cm ga teng.

# %% [markdown]
# # String (matn) mavzusida amalyot

# %% [markdown]
# 1. Quyidagi mashqlarni bajaring:
#
# Quyidagi o'zgaruvchilarni yarating:
#
# kocha="Bog'bon"
#
# mahalla="Sog'bon"
#
# tuman="Bodomzor"
#
# viloyat="Samarqand"

# %%
kocha = "Bog'bon"
mahalla = "Sog'bon"
tuman = "Bodomzor"
viloyat = "Samarqand"

# %% [markdown]
# 2. Yuqoridagi o'zgaruvchilarni jamlab, quyidagi ko'rinishda konsolga chiqaring:
#
# Bog'bon ko'chasi, Sog'bon mahallasi, Bodomzor tumani, Samarqand viloyati

# %%
natija = f"{kocha} ko'chasi, {mahalla} mahallasi, {tuman} tumani, {viloyat} viloyati"
print(natija)
# Out:
# Bog'bon ko'chasi, Sog'bon mahallasi, Bodomzor tumani, Samarqand viloyati

# %% [markdown]
# 3. Yuqoridagi o'zgaruvchilarning (kocha, mahalla, tuman, viloyat) qiymatini foydalanuvchidan so'rang. Va avvalgi mashqni takrorlang.

# %%
kocha = input("Ko'changiz nomini kiriting: ")
mahalla = input("mahallangiz nomini kiriting: ")
tuman = input("tumaningiz nomini kiriting: ")
viloyat = input("Viloyatingiz nomini kiriting: ")

natija = f"{kocha} ko'chasi, {mahalla} mahallasi, {tuman} tumani, {viloyat} viloyati"
print(natija)
# Out:
# Ko'changiz nomini kiriting: N
# mahallangiz nomini kiriting: B
# tumaningiz nomini kiriting: Y
# Viloyatingiz nomini kiriting: S
# N ko'chasi, B mahallasi, Y tumani, S viloyati

# %% [markdown]
# 4. Yuqoridagi matnni konsolga chiqarishda har bir verguldan keyin yangi qatordan yozing

# %%
kocha = input("Ko'changiz nomini kiriting: ")
mahalla = input("mahallangiz nomini kiriting: ")
tuman = input("tumaningiz nomini kiriting: ")
viloyat = input("Viloyatingiz nomini kiriting: ")

natija = f"{kocha} ko'chasi, \n{mahalla} mahallasi, \n{tuman} tumani, \n{viloyat} viloyati"
print(natija)
# Out:
# Ko'changiz nomini kiriting: A
# mahallangiz nomini kiriting: B
# tumaningiz nomini kiriting: C
# Viloyatingiz nomini kiriting: D
# A ko'chasi,
# B mahallasi,
# C tumani,
# D viloyati

# %% [markdown]
# 5. Yuqoridagi matnni f-string yordamida, yangi, manzil deb nomlangan o'zgaruvchiga yuklang:
# - manzilga biz yuqorida o'rgangan title(), upper(), lower() , capitalize() metodlarini qo'llab ko'ring.

# %%
manzil = f"{kocha} ko'chasi, \n{mahalla} mahallasi, \n{tuman} tumani, \n{viloyat} viloyati"
print(manzil.title())
# Out:
# A Ko'Chasi,
# B Mahallasi,
# C Tumani,
# D Viloyati

# %% [markdown]
# 6. Quyidagi o'zgaruvchilarni yarating:
#
# kocha="Bog'bon"
#
# mahalla="Sog'bon"
#
# tuman="Bodomzor"
#
# viloyat="Samarqand"

# %%
kocha="Bog'bon"

mahalla="Sog'bon"

tuman="Bodomzor"

viloyat="Samarqand"
# Out:
# Bog'bon ko'chasi, Sog'bon mahallasi, Bodomzor tumani, Samarqand viloyati

# %% [markdown]
# 7. Yuqoridagi o'zgaruvchilarni jamlab, quyidagi ko'rinishda konsolga chiqaring:
#
# Bog'bon ko'chasi, Sog'bon mahallasi, Bodomzor tumani, Samarqand viloyati

# %%
kocha="Bog'bon"

mahalla="Sog'bon"

tuman="Bodomzor"

viloyat="Samarqand"

manzil = f"{kocha} ko'chasi, {mahalla} mahallasi, {tuman} tumani, {viloyat} viloyati"
print(manzil)
# Out:
# Bog'bon ko'chasi, Sog'bon mahallasi, Bodomzor tumani, Samarqand viloyati

# %% [markdown]
# 8. Yuqoridagi o'zgaruvchilarning (kocha, mahalla, tuman, viloyat) qiymatini foydalanuvchidan so'rang. Va avvalgi mashqni takrorlang.

# %%
kocha = input("Ko'changizni nomini kiriting: ")
mahalla = input("Mahallangizning nomini kiriting: ")
tuman = input("Tumaningizning nomini kiriting: ")
viloyat = input("Viloyatingiz nomini kiriting: ")

manzil = f"{kocha} ko'chasi, {mahalla} mahallasi, {tuman} tumani, {viloyat} viloyati"
print(manzil)
# Out:
# Ko'changizni nomini kiriting: A
# Mahallangizning nomini kiriting: B
# Tumaningizning nomini kiriting: C
# Viloyatingiz nomini kiriting: D
# A ko'chasi, B mahallasi, C tumani, D viloyati

# %% [markdown]
# 9. Yuqoridagi matnni konsolga chiqarishda har bir verguldan keyin yangi qatordan yozing

# %%
manzil = f"{kocha} ko'chasi, \n{mahalla} mahallasi, \n{tuman} tumani, \n{viloyat} viloyati"
print(manzil)
# Out:
# A ko'chasi,
# B mahallasi,
# C tumani,
# D viloyati

# %% [markdown]
# 10. Yuqoridagi o'zgaruvchilarni f-string yordamida, yangi, manzil deb nomlangan o'zgaruvchiga yuklang
#
# manzilga biz yuqorida o'rgangan title(), upper(), lower() , capitalize() metodlarini qo'llab ko'ring.

# %%
print(manzil.upper())
# Out:
# A KO'CHASI,
# B MAHALLASI,
# C TUMANI,
# D VILOYATI

# %%
print(manzil.title())
# Out:
# A Ko'Chasi,
# B Mahallasi,
# C Tumani,
# D Viloyati

# %%
print(manzil.lower())
# Out:
# a ko'chasi,
# b mahallasi,
# c tumani,
# d viloyati

# %%
print(manzil.capitalize())
# Out:
# A ko'chasi,
# b mahallasi,
# c tumani,
# d viloyati

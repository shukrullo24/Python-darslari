# %% [markdown]
# <a href="https://colab.research.google.com/github/shukrullo24/Python-darslari/blob/main/O'zgaruvchilar_va_ma'lumot_turlari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sonlar
#
# > Pythonda sonlar bilna ishlash bo'yicha amaliy mashqlar
#
#
# Quyidagi dasturlarning har birini alohida fayl ko'rinishida yozing va bajaring:
#
# Foydalanuvchi kiritgan sonning kvadrati va kubini konsolga chiqaruvchi dastur yozing

# %%
son_1 = int(input("Istalgan son kiriting, uning kvadrati va kubini hisoblab beraman: "))
kv = son_1**2
kub = son_1**3

natija = "Kiritilgan sonning kvadrati ", kv, "ga teng, kubi esa ", kub, "ga teng"
print(natija)
# Out:
# Istalgan son kiriting, uning kvadrati va kubini hisoblab beraman: 14
# ('Kiritilgan sonning kvadrati ', 196, 'ga teng, kubi esa ', 2744, 'ga teng')

# %% [markdown]
# Foydalanvuchining yoshini so'rab uning tug'ilgan yilini konsolga chiqaruvchi dastur

# %%
yosh = int(input("Yoshingizni kiriting: "))
yil = 2026
natija = yil - yosh
print(f"Siz {natija}-yilda tug'ilgnasiz")
# Out:
# Yoshingizni kiriting: 28
# Siz 1998-yilda tug'ilgnasiz

# %% [markdown]
# Foydalanuvchidan ikki son kiritishini so'rab, sonlarning yig'indisi, ayirmasi, ko'paytmasi va bo'linmasini chiqaruvchi dastur

# %%
print("Kiritilgan sonlarning yig'indisi, ayirmasi, ko'paytmasi va bo'linmasini hisoblaymiz")
num_1 = int(input("Birinchi sonni kiriting: "))
num_2 = int(input("Ikkinchi sonni kiriting: "))

yigindi = num_1 + num_2
ayirma = num_1 - num_2
kopaytma = num_1 * num_2
bolinma = num_1 / num_2

natija_1 = [yigindi, ayirma, kopaytma, bolinma]
natija_2 = f"Kiritilgan sonlarning yig'indisi {yigindi}, ayirmasi {ayirma}, ko'paytmasi {kopaytma}, bo'linmasi {bolinma} ga teng."
print(natija_1)
print(natija_2)
# Out:
# Kiritilgan sonlarning yig'indisi, ayirmasi, ko'paytmasi va bo'linmasini hisoblaymiz
# Birinchi sonni kiriting: 15
# Ikkinchi sonni kiriting: 20
# [35, -5, 300, 0.75]
# Kiritilgan sonlarning yig'indisi 35, ayirmasi -5, ko'paytmasi 300, bo'linmasi 0.75 ga teng.

# %% [markdown]
# # List (Ro'yxat)

# %% [markdown]
# `ismlar` degna ro'yxat yarating va kamida 3 ta yaqin do'stingizning ismini kiriting.
# Ro'yxatdagi har bir do'stingizga qisqa xabar yozib konsolga chiqaring:
# "Salom Abror, bugun choyxona bormi?
# Mahmud, choyxonaga boramizmi?"

# %%
ismlar = ['oybek', 'maqsud', 'islom']
print(f"Salom {ismlar[0].title()}, bugun choyxona bormi?")
print(f"Salom {ismlar[1].title()}, bugun choyxona bormi?")
print(f"Salom {ismlar[2].title()}, bugun choyxona bormi?")
# Out:
# Salom Oybek, bugun choyxona bormi?
# Salom Maqsud, bugun choyxona bormi?
# Salom Islom, bugun choyxona bormi?

# %% [markdown]
# `sonlar` deb nomlangan ro'yxat yarating va ichiga turli sonlarni yuklang (musbat, manfiy, butun, o'nlik)

# %%
sonlar = [10, -20, 35, 12.5]

# %% [markdown]
# Yuqoridagi sonlar ustida turli arifmetik amallar bajarib ko'ring.
# Ro'yxatdagi ba'zi sonlarning qiymatini o'zgartiring, ba'zilarini esa almshtiring

# %%
sonlar = [10, -20, 35, 12.5]
sonlar.remove(10)
print(sonlar)
# Out:
# [-20, 35, 12.5]

# %%
sonlar = [10, -20, 35, 12.5]
sonlar.remove(10)
print(sonlar)
sonlar.insert(0, 25)
print(sonlar)
# Out:
# [-20, 35, 12.5]
# [25, -20, 35, 12.5]

# %% [markdown]
# Index yordamida elementni o'chiramiz

# %%
del sonlar[3]
print(sonlar)
# Out:
# [25, -20, 35]

# %%
del sonlar[-1]
sonlar
# Out:
# [25, -20]

# %%
sonlar = [15, 11, 33, 28, 24.5]
son = sonlar.pop(4)
print(f"Men tanlagan son {son} soni")
print(f"Qolgan solar esa: {sonlar}")
# Out:
# Men tanlagan son 24.5 soni
# Qolgan solar esa: [15, 11, 33, 28]

# %% [markdown]
# `t_shaxslar` va `z_shaxslar` degan 2 ta ro'yxat yarating va biriga o'zingiz eng ko'p hurmat qilgan tarixiy shaxslarning, ikkinchisiga esa zamonamizdagi tirik bo'lgan shaxslarning ismini kiriting.

# %%
t_shaxslar = ["Alixonto'ra Sog'uniy", "Abdurauf Fitrat", "Shermuhammad"]
z_shaxslar = ["Anvar Narzullayev", "Abdulloh", "Akrom Malik"]

print(t_shaxslar)
print(z_shaxslar)
# Out:
# ["Alixonto'ra Sog'uniy", 'Abdurauf Fitrat', 'Shermuhammad']
# ['Anvar Narzullayev', 'Abdulloh', 'Akrom Malik']

# %% [markdown]
# Yuqoridagi ro'yxatlarning har biridan bittadan qiymatni sug'urib olib (.pop()), quyidagi ko'rinishda chiqaring:

# %%
natija = f"Men tarixiy shaxslardan {t_shaxslar.pop(0)} bilan, zamonaviy shaxslardan esa {z_shaxslar.pop(2)} bilan suhbatlashishni xohlar edim."
print(natija)
# Out:
# Men tarixiy shaxslardan Alixonto'ra Sog'uniy bilan, zamonaviy shaxslardan esa Akrom Malik bilan suhbatlashishni xohlar edim.

# %% [markdown]
# `friends` nomli bo'sh ro'yxat tuzing va unga .append() yordamida 5-6 ta mehmonga chaqirmoqchi bo'lgan do'stlaringizni kiriting.
#
# Yuqoridagi ro'yxatdan mehmonga kela olmaydigan odamlarni .remove() metodi yordamida o'chrib tashlang.

# %%
friends = []

friends.append("Oybek")
friends.append("Shohjahon")
friends.append("Muzaffar")
friends.append("Maqsud")
friends.append("Iqbol")

friends.remove("Maqsud")
friends.remove("Muzaffar")
friends
# Out:
# ['Oybek', 'Shohjahon', 'Iqbol']

# %% [markdown]
# Ro'yxatning oxiriga, boshiga va o'rtasiga yangi ismlar qo'shing.

# %%
friends.insert(0, "Islom")
friends.insert(2, "G'ayrat")
friends.insert(-1, "Bobur")
friends
# Out:
# ['Islom', 'Oybek', "G'ayrat", 'Shohjahon', 'Bobur', 'Iqbol']

# %% [markdown]
# Yangi `mehmonlar` deb nomlangan bo'sh ro'yxat yarating. `.pop()` va `.append()` metodlari yordamida mehmonga kelgan do'stlaringizning ismini friends ro'yxatidan sug'urib olib, mehmonlar ro'yxatiga qo'shing.

# %%
guests = []
guests.append(friends.pop(0))
guests.append(friends.pop(0))
guests.append(friends.pop(0))
print(f"To'yga kelgan mehmonlar {guests}")
# Out:
# To'yga kelgan mehmonlar ['Islom', 'Oybek', "G'ayrat"]

# %%
friends
mehmonlar = []
mehmonlar.append(friends.pop(-1))
print("\nKelgan mehmonlar: ", mehmonlar)
# Out:
# Kelgan mehmonlar:  ['Iqbol']
